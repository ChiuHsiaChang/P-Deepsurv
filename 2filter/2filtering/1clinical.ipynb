# %%
import numpy as np
import pandas as pd

# %%
clinical_df = pd.read_csv('D:\\2020\\資料科學\\final-project\\clinical\\clinical.tsv',sep='\t',engine='python')

# %%
clinical_df.isnull().sum()
# Out:
# case_id                                  0
# case_submitter_id                        0
# project_id                               0
# age_at_index                             0
# age_is_obfuscated                     2194
# cause_of_death                        2194
# cause_of_death_source                 2194
# country_of_residence_at_enrollment    2194
# days_to_birth                           30
# days_to_death                         1892
# ethnicity                                0
# gender                                   0
# occupation_duration_years             2194
# premature_at_birth                    2194
# race                                     0
# vital_status                             0
# weeks_gestation_at_birth              2194
# year_of_birth                            6
# year_of_death                         1986
# age_at_diagnosis                        30
# ajcc_clinical_m                       2194
# ajcc_clinical_n                       2194
# ...

# %%
clinical_df.shape[1]
# Out:
# 154

# %%
clinical_df.head()
# Out:
#                                 case_id case_submitter_id project_id  \
# 0  fec0da58-1047-44d2-b6d1-c18cceed43dc      TCGA-E9-A295  TCGA-BRCA
# 1  fec0da58-1047-44d2-b6d1-c18cceed43dc      TCGA-E9-A295  TCGA-BRCA
# 2  a4903de8-6cf5-4541-8ec7-065beace8b44      TCGA-AO-A0J9  TCGA-BRCA
# 3  a4903de8-6cf5-4541-8ec7-065beace8b44      TCGA-AO-A0J9  TCGA-BRCA
# 4  791c5768-f0f5-4ab6-86eb-998e5c4b49e3      TCGA-E2-A1L7  TCGA-BRCA
#
#    age_at_index  age_is_obfuscated  cause_of_death  cause_of_death_source  \
# 0            71                NaN             NaN                    NaN
# 1            71                NaN             NaN                    NaN
# 2            61                NaN             NaN                    NaN
# 3            61                NaN             NaN                    NaN
# 4            40                NaN             NaN                    NaN
#
#    country_of_residence_at_enrollment  days_to_birth  days_to_death  \
# ...

# %%
col = clinical_df.columns.tolist()
clinical_df[col[4]].isnull().sum()
# Out:
# 2194

# %%
col = clinical_df.columns.tolist()
j = clinical_df.shape[1]
for i in range(j):
    if clinical_df[col[i]].isnull().sum()==2194:
        clinical_df.drop(labels=[col[i]],axis=1,inplace=True)
clinical_df.isnull().sum()
# Out:
# case_id                           0
# case_submitter_id                 0
# project_id                        0
# age_at_index                      0
# days_to_birth                    30
# days_to_death                  1892
# ethnicity                         0
# gender                            0
# race                              0
# vital_status                      0
# year_of_birth                     6
# year_of_death                  1986
# age_at_diagnosis                 30
# ajcc_pathologic_m                 0
# ajcc_pathologic_n                 0
# ajcc_pathologic_stage            22
# ajcc_pathologic_t                 0
# ajcc_staging_system_edition     282
# classification_of_tumor           0
# days_to_diagnosis                 0
# days_to_last_follow_up          208
# icd_10_code                       0
# last_known_disease_status         0
# morphology                        0
# primary_diagnosis                 0
# prior_malignancy                  0
# ...

# %%
clinical_df.head()
# Out:
#                                 case_id case_submitter_id project_id  \
# 0  fec0da58-1047-44d2-b6d1-c18cceed43dc      TCGA-E9-A295  TCGA-BRCA
# 1  fec0da58-1047-44d2-b6d1-c18cceed43dc      TCGA-E9-A295  TCGA-BRCA
# 2  a4903de8-6cf5-4541-8ec7-065beace8b44      TCGA-AO-A0J9  TCGA-BRCA
# 3  a4903de8-6cf5-4541-8ec7-065beace8b44      TCGA-AO-A0J9  TCGA-BRCA
# 4  791c5768-f0f5-4ab6-86eb-998e5c4b49e3      TCGA-E2-A1L7  TCGA-BRCA
#
#    age_at_index  days_to_birth  days_to_death               ethnicity  gender  \
# 0            71       -25957.0            NaN  not hispanic or latino  female
# 1            71       -25957.0            NaN  not hispanic or latino  female
# 2            61       -22642.0            NaN  not hispanic or latino  female
# 3            61       -22642.0            NaN  not hispanic or latino  female
# 4            40       -14854.0            NaN  not hispanic or latino  female
#
#     race vital_status             ...               prior_treatment  \
# ...

# %%
clinical_df.drop_duplicates('case_id','first',inplace=True)
clinical_df.head()
# Out:
#                                 case_id case_submitter_id project_id  \
# 0  fec0da58-1047-44d2-b6d1-c18cceed43dc      TCGA-E9-A295  TCGA-BRCA
# 2  a4903de8-6cf5-4541-8ec7-065beace8b44      TCGA-AO-A0J9  TCGA-BRCA
# 4  791c5768-f0f5-4ab6-86eb-998e5c4b49e3      TCGA-E2-A1L7  TCGA-BRCA
# 6  17ca61a2-607a-45ff-88fa-ef72e80bf891      TCGA-BH-A0HF  TCGA-BRCA
# 8  db8d38ab-cc61-49ee-863d-40060112f2af      TCGA-A8-A08H  TCGA-BRCA
#
#    age_at_index  days_to_birth  days_to_death               ethnicity  gender  \
# 0            71       -25957.0            NaN  not hispanic or latino  female
# 2            61       -22642.0            NaN  not hispanic or latino  female
# 4            40       -14854.0            NaN  not hispanic or latino  female
# 6            77       -28233.0            NaN            not reported  female
# 8            66       -24137.0            NaN            not reported  female
#
#            race vital_status             ...               prior_treatment  \
# ...

# %%
clinical_df.to_csv('D:\\2020\\資料科學\\final-project\\clinical\\clinical_1.csv',index=False)

# %%
clinical_df.iloc[0,1]
# Out:
# 'TCGA-E9-A295'

# %%
normal = np.loadtxt('D:\\2020\資料科學\\final-project\\tcga_files\\rename\\edgeR\\normalizeExp.txt',dtype='str')
normal_df = pd.DataFrame(normal)

# %%
normal_df.iloc[0]=normal_df.iloc[0].apply(lambda x: x[:12])
normal_df.iloc[0]
# Out:
# 0                 id
# 1       TCGA-BH-A1FH
# 2       TCGA-A7-A13E
# 3       TCGA-BH-A0DK
# 4       TCGA-BH-A18Q
# 5       TCGA-BH-A0BJ
# 6       TCGA-BH-A1FD
# 7       TCGA-BH-A1FN
# 8       TCGA-AC-A2FM
# 9       TCGA-E9-A1NA
# 10      TCGA-E9-A1RD
# 11      TCGA-A7-A0D9
# 12      TCGA-E9-A1RB
# 13      TCGA-E2-A1L7
# 14      TCGA-E2-A1BC
# 15      TCGA-E2-A1LB
# 16      TCGA-BH-A0BC
# 17      TCGA-BH-A0HA
# 18      TCGA-E9-A1R7
# 19      TCGA-BH-A0DD
# 20      TCGA-BH-A208
# 21      TCGA-BH-A1FM
# 22      TCGA-A7-A0DB
# 23      TCGA-BH-A0BQ
# 24      TCGA-E2-A1IG
# 25      TCGA-BH-A0B3
# 26      TCGA-BH-A1F0
# 27      TCGA-GI-A2C8
# 28      TCGA-E9-A1RI
# 29      TCGA-AC-A23H
#             ...
# 1193    TCGA-D8-A1JD
# 1194    TCGA-A2-A0CV
# 1195    TCGA-E2-A14V
# 1196    TCGA-E2-A153
# 1197    TCGA-AR-A24R
# 1198    TCGA-AR-A1AV
# 1199    TCGA-OL-A66H
# 1200    TCGA-AR-A251
# 1201    TCGA-AC-A7VB
# 1202    TCGA-A8-A08C
# 1203    TCGA-A2-A259
# 1204    TCGA-AO-A03P
# ...

# %%
normal_df.to_csv('D:\\2020\\資料科學\\final-project\\clinical\\normalized_gene.csv',header=False,index=False)
